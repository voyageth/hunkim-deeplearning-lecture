# %%
import tensorflow as tf
import numpy as np

xy = np.loadtxt('data/lab05_train.txt', unpack=True, dtype='float32')
x_data = xy[0:-1]
y_data = xy[-1]

X = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)

W = tf.Variable(tf.random_uniform([1, len(x_data)], -1.0, 1.0))

h = tf.matmul(W, X)
hypothesis = tf.div(1., 1. + tf.exp(-h))
cost = -tf.reduce_mean(Y * tf.log(hypothesis) + (1-Y) * tf.log(1-hypothesis))

a = tf.Variable(0.1)
optimizer = tf.train.GradientDescentOptimizer(a)
train = optimizer.minimize(cost)

init = tf.global_variables_initializer()

sess = tf.Session()
sess.run(init)

for step in range(2001):
    sess.run(train, feed_dict={X:x_data, Y:y_data})
    if step % 20 == 0:
        print(step, "cost:%s, W:%s"%(sess.run(cost, feed_dict={X:x_data, Y:y_data}), sess.run(W)))
# Out:
# 0 cost:1.23122, W:[[ 0.55523074 -0.16714196 -0.33493909]]
# 20 cost:0.70056, W:[[ 0.33985916  0.02063082  0.03400402]]
# 40 cost:0.664354, W:[[ 0.08124624  0.00654631  0.10710457]]
# 60 cost:0.633482, W:[[-0.16197106  0.01157221  0.15831038]]
# 80 cost:0.60657, W:[[-0.39031109  0.02517785  0.19785702]]
# 100 cost:0.582944, W:[[-0.60462075  0.04234577  0.23080178]]
# 120 cost:0.562134, W:[[-0.80586833  0.06066347  0.25970033]]
# 140 cost:0.543752, W:[[-0.99504429  0.07897574  0.28588519]]
# 160 cost:0.527467, W:[[-1.17311215  0.09674236  0.31008357]]
# 180 cost:0.512994, W:[[-1.3409816   0.11372624  0.33271745]]
# 200 cost:0.500087, W:[[-1.49949813  0.12984076  0.35405102]]
# 220 cost:0.488539, W:[[-1.6494385   0.14507371  0.37426353]]
# 240 cost:0.47817, W:[[-1.79151177  0.15944941  0.39348614]]
# 260 cost:0.468828, W:[[-1.92636013  0.17300907  0.41182047]]
# 280 cost:0.460382, W:[[-2.05456614  0.18580094  0.42934945]]
# 300 cost:0.452723, W:[[-2.17665601  0.1978752   0.44614255]]
# 320 cost:0.445755, W:[[-2.29310489  0.20928124  0.46225932]]
# 340 cost:0.439396, W:[[-2.40434241  0.22006635  0.47775197]]
# 360 cost:0.433576, W:[[-2.51075602  0.23027465  0.49266627]]
# 380 cost:0.428235, W:[[-2.61269641  0.23994738  0.50704294]]
# 400 cost:0.42332, W:[[-2.71048141  0.24912278  0.52091855]]
# 420 cost:0.418786, W:[[-2.80439854  0.25783584  0.53432584]]
# 440 cost:0.414593, W:[[-2.8947103   0.266119    0.54729456]]
# 460 cost:0.410707, W:[[-2.98165512  0.27400202  0.55985153]]
# 480 cost:0.407097, W:[[-3.06544924  0.28151205  0.57202137]]
# 500 cost:0.403736, W:[[-3.14629126  0.28867394  0.58382654]]
# 520 cost:0.400602, W:[[-3.22436285  0.29551068  0.59528756]]
# 540 cost:0.397673, W:[[-3.2998302   0.30204347  0.60642314]]
# 560 cost:0.394931, W:[[-3.37284613  0.30829158  0.6172508 ]]
# 580 cost:0.39236, W:[[-3.44354987  0.31427276  0.62778646]]
# 600 cost:0.389945, W:[[-3.51207232  0.32000345  0.63804501]]
# 620 cost:0.387673, W:[[-3.5785315   0.32549879  0.64804018]]
# 640 cost:0.385533, W:[[-3.64303803  0.33077264  0.65778464]]
# 660 cost:0.383513, W:[[-3.70569491  0.33583796  0.66729045]]
# 680 cost:0.381605, W:[[-3.7665956   0.34070656  0.67656839]]
# 700 cost:0.3798, W:[[-3.82582831  0.3453896   0.68562889]]
# 720 cost:0.37809, W:[[-3.8834753   0.34989735  0.69448155]]
# 740 cost:0.376468, W:[[-3.93961263  0.35423931  0.70313543]]
# 760 cost:0.374929, W:[[-3.99431157  0.35842422  0.71159905]]
# 780 cost:0.373465, W:[[-4.04763746  0.36246043  0.7198801 ]]
# 800 cost:0.372073, W:[[-4.09965324  0.36635545  0.72798622]]
# 820 cost:0.370746, W:[[-4.15041685  0.3701165   0.73592442]]
# 840 cost:0.369482, W:[[-4.19998264  0.37375036  0.74370122]]
# 860 cost:0.368275, W:[[-4.24840164  0.37726316  0.75132269]]
# 880 cost:0.367122, W:[[-4.29572296  0.3806608   0.75879514]]
# 900 cost:0.36602, W:[[-4.34198999  0.3839488   0.76612365]]
# 920 cost:0.364966, W:[[-4.38724709  0.38713223  0.77331388]]
# 940 cost:0.363956, W:[[-4.43153191  0.39021581  0.78037018]]
# 960 cost:0.362988, W:[[-4.47488546  0.39320436  0.78729802]]
# 980 cost:0.36206, W:[[-4.51734161  0.39610183  0.79410154]]
# 1000 cost:0.361169, W:[[-4.55893469  0.39891249  0.80078483]]
# 1020 cost:0.360314, W:[[-4.59969616  0.40163991  0.80735201]]
# 1040 cost:0.359491, W:[[-4.63965702  0.40428776  0.81380707]]
# 1060 cost:0.3587, W:[[-4.67884493  0.40685925  0.8201533 ]]
# 1080 cost:0.357939, W:[[-4.71728897  0.40935794  0.82639456]]
# 1100 cost:0.357206, W:[[-4.75501394  0.41178656  0.83253402]]
# 1120 cost:0.3565, W:[[-4.79204512  0.414148    0.83857483]]
# 1140 cost:0.355819, W:[[-4.82840538  0.41644496  0.84452009]]
# 1160 cost:0.355162, W:[[-4.86411762  0.41867998  0.85037255]]
# 1180 cost:0.354527, W:[[-4.89920139  0.42085534  0.85613501]]
# 1200 cost:0.353915, W:[[-4.9336791   0.42297357  0.86181015]]
# 1220 cost:0.353323, W:[[-4.9675684   0.4250367   0.86740047]]
# 1240 cost:0.352751, W:[[-5.00088882  0.4270469   0.87290835]]
# 1260 cost:0.352198, W:[[-5.03365755  0.42900619  0.87833607]]
# 1280 cost:0.351662, W:[[-5.06589174  0.43091634  0.88368595]]
# 1300 cost:0.351144, W:[[-5.09760666  0.43277904  0.88896012]]
# 1320 cost:0.350642, W:[[-5.12881804  0.43459609  0.89416051]]
# 1340 cost:0.350155, W:[[-5.15954161  0.43636924  0.89928919]]
# 1360 cost:0.349684, W:[[-5.18978977  0.43809974  0.90434802]]
# 1380 cost:0.349226, W:[[-5.21957731  0.43978935  0.90933877]]
# 1400 cost:0.348783, W:[[-5.24891758  0.44143933  0.91426331]]
# 1420 cost:0.348352, W:[[-5.27782106  0.44305098  0.91912317]]
# 1440 cost:0.347934, W:[[-5.30630112  0.44462562  0.92391992]]
# 1460 cost:0.347528, W:[[-5.33436871  0.44616452  0.92865509]]
# 1480 cost:0.347133, W:[[-5.36203671  0.44766897  0.93333066]]
# 1500 cost:0.346749, W:[[-5.38931179  0.44913977  0.93794727]]
# 1520 cost:0.346376, W:[[-5.41620731  0.45057824  0.94250679]]
# 1540 cost:0.346014, W:[[-5.44273329  0.45198551  0.94701082]]
# 1560 cost:0.34566, W:[[-5.46889925  0.45336241  0.95146048]]
# 1580 cost:0.345317, W:[[-5.49471283  0.4547098   0.95585686]]
# 1600 cost:0.344982, W:[[-5.52018404  0.45602879  0.96020138]]
# 1620 cost:0.344656, W:[[-5.54531956  0.45732003  0.96449488]]
# 1640 cost:0.344339, W:[[-5.57012939  0.45858452  0.96873879]]
# 1660 cost:0.34403, W:[[-5.5946207   0.4598231   0.97293407]]
# 1680 cost:0.343728, W:[[-5.61880112  0.4610365   0.97708184]]
# 1700 cost:0.343434, W:[[-5.64267778  0.46222526  0.98118305]]
# 1720 cost:0.343147, W:[[-5.66625834  0.46339041  0.98523879]]
# 1740 cost:0.342867, W:[[-5.68954849  0.46453241  0.98924989]]
# 1760 cost:0.342594, W:[[-5.71255732  0.46565205  0.99321765]]
# 1780 cost:0.342328, W:[[-5.73528862  0.46674994  0.99714255]]
# 1800 cost:0.342067, W:[[-5.75775051  0.46782675  1.00102568]]
# 1820 cost:0.341813, W:[[-5.77994776  0.46888274  1.00486791]]
# 1840 cost:0.341565, W:[[-5.8018856   0.46991879  1.00866997]]
# 1860 cost:0.341322, W:[[-5.82357073  0.47093549  1.01243258]]
# 1880 cost:0.341085, W:[[-5.84500885  0.47193331  1.01615655]]
# 1900 cost:0.340853, W:[[-5.86620474  0.47291252  1.01984286]]
# 1920 cost:0.340626, W:[[-5.88716364  0.47387394  1.0234921 ]]
# 1940 cost:0.340405, W:[[-5.9078908   0.47481796  1.02710497]]
# 1960 cost:0.340188, W:[[-5.9283905   0.4757449   1.03068209]]
# 1980 cost:0.339976, W:[[-5.94866753  0.4766553   1.03422439]]
# 2000 cost:0.339768, W:[[-5.96872711  0.47754955  1.03773236]]

# %% [markdown]
# # Ask to ML

# %%
print(sess.run(hypothesis, feed_dict={X:[[1], [2], [2]]}) > 0.5)
print(sess.run(hypothesis, feed_dict={X:[[1], [5], [5]]}) > 0.5)
print(sess.run(hypothesis, feed_dict={X:[[1, 1], [4, 3], [3, 5]]}) > 0.5)
# Out:
# [[False]]
# [[ True]]
# [[False  True]]
